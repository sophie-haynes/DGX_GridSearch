# %% [markdown]
# This notebook takes the raw prediction outputs, performs mapping to metadata files, and produces summary metrics.

# %%
import pandas as pd
import os

# %%
# helper to load pred files
def load_predictions_df(backbone, training_strategy, seed, dataset, base_path = "/home/local/data/sophie/DGX_GridSearch/raw_predictions/"):
    """
    Helper to fetch predictions dataframe.

    Args: 
        backbone (string): Training Backbone (e.g. base, base65, grey, grey65, single, single65)
        training_strategy (string): Network training strategy (e.g. half, first, full)
        seed (int): Seed used for model training (e.g. 42, 43, 44)
        dataset (string): Name of eval dataset (e.g. cxr14, padchest, openi, jsrt)
        base_path (string, optional): Directory containing prediction file

    Returns:
        dataframe: predictions dataframe
    """
    return pd.read_csv(os.path.join(base_path, f"preds_{backbone}_{training_strategy}_seed{seed}_{dataset}.csv"))

# %%
meta_data = pd.read_csv("/home/local/data/sophie/processed_meta_full.csv")

# %%
meta_data['img_name'] = meta_data['mha'].apply(lambda x: x[:-4])
meta_data.head(1)
# Out:
#   original_image_name orig_dataset  label        mha Finding Labels  \
# 0        00010496_001  chestxray14      1  n0239.mha         Nodule
#
#   Patient ID  Patient Age Patient Gender  original_image_width  \
# 0      10496         44.0              M                2992.0
#
#    original_image_height  ...  shared_image_width  shared_image_height  \
# 0                 2991.0  ...                1024                 1024
#
#   Study Year  Manufacturer  Modality  subtlety  nodule_size  malignant  \
# 0        NaN           NaN       NaN       NaN          NaN        NaN
#
#    Partition  img_name
# 0      Train     n0239
#
# [1 rows x 27 columns]

# %%
# helper to convert raw outputs to binary preds
def get_max_pred(x):
    return 1 if x['pred_0'] < x['pred_1'] else 0
def pred_based_on_pos_logit(x):
    return 1 if x['pred_1'] >= 0.5 else 0

# %%
test_df = load_predictions_df("base", "full", 42, "cxr14")
test_df['pred_int'] = test_df.apply(get_max_pred, axis=1)
test_df['pred1_thresh_int'] = test_df['pred_1'].apply(lambda x: 1 if x >= 0.5 else 0)
test_df['pred0_thresh_int'] = test_df['pred_0'].apply(lambda x: 0 if x >= 0.5 else 1)
test_df.head(5)
# Out:
#   img_name  true_label    pred_0    pred_1  pred_int  pred1_thresh_int  \
# 0    c0021           0  0.720273 -0.135957         0                 0
# 1    c0029           0  0.162161 -0.043217         0                 0
# 2    c0034           0  1.091611 -0.891011         0                 0
# 3    c0035           0  0.063651  0.094966         1                 0
# 4    c0056           0  1.180160 -0.596414         0                 0
#
#    pred0_thresh_int
# 0                 0
# 1                 1
# 2                 0
# 3                 1
# 4                 0

# %%
mapped_df = test_df.merge(meta_data, how="left", on="img_name")
mapped_df.head(1)
# Out:
#   img_name  true_label    pred_0    pred_1  pred_int  pred1_thresh_int  \
# 0    c0021           0  0.720273 -0.135957         0                 0
#
#    pred0_thresh_int original_image_name orig_dataset  label  ...  \
# 0                 0        00000425_001  chestxray14      0  ...
#
#   orig_bbox_height shared_image_width shared_image_height  Study Year  \
# 0                0               1024                1024         NaN
#
#   Manufacturer  Modality  subtlety  nodule_size  malignant Partition
# 0          NaN       NaN       NaN          NaN        NaN      Test
#
# [1 rows x 33 columns]

# %%
tp = len(mapped_df.query("true_label == pred_int and true_label==1"))
tn = len(mapped_df.query("true_label == pred_int and true_label==0"))
fp = len(mapped_df.query("true_label != pred_int and true_label==0"))
fn = len(mapped_df.query("true_label != pred_int and true_label==1"))

# %%
def calc_prec(tp, fp):
    return tp/(tp+fp)
def calc_rec(tp, fn):
    return tp/(tp+fn)
def calc_spec(tn, fp):
    return tn/(tn+fp)

# %%
print(f"Accuracy: {round(len(mapped_df.query('true_label == pred_int'))/len(mapped_df),4)*100}%")
print(f"Precision: {round(calc_prec(tp, fp),4)}")
print(f"Recall/Sens: {round(calc_rec(tp, fn),4)}")
print(f"Spec: {round(calc_spec(tn, fp),4)}")
# Out:
# Accuracy: 84.72%
# Precision: 0.8655
# Recall/Sens: 0.8222
# Spec: 0.8722

# %%
len(mapped_df.query("true_label != pred1_thresh_int and true_label==1"))

# %%
calc_prec(len(mapped_df.query("true_label == pred1_thresh_int and true_label==1")), len(mapped_df.query("true_label != pred1_thresh_int and true_label==0")))
# Out:
# 0.9194630872483222

# %%
# Out:
# 0.7611111111111111

# %%
print(f"Accuracy 1: {round(len(mapped_df.query('true_label == pred_int'))/len(mapped_df),4)*100}%")
print(f"Precision: {round(calc_prec(tp, fp),4)}")
print(f"Recall/Sens: {round(calc_rec(tp, fn),4)}")
print(f"Spec: {round(calc_spec(tn, fp),4)}")
print(f"Accuracy 2: {round(len(mapped_df.query('true_label == pred1_thresh_int'))/len(mapped_df),4)*100}%")
print(f'Precision: {round(calc_prec(len(mapped_df.query("true_label == pred1_thresh_int and true_label==1")), len(mapped_df.query("true_label != pred1_thresh_int and true_label==0"))),4)}')
print(f'Recall/Sens: {round(calc_rec(len(mapped_df.query("true_label == pred1_thresh_int and true_label==1")), len(mapped_df.query("true_label != pred1_thresh_int and true_label==1"))),4)}')
print(f'Spec: {round(calc_spec(len(mapped_df.query("true_label == pred1_thresh_int and true_label==0")), len(mapped_df.query("true_label != pred1_thresh_int and true_label==0"))),4)}')
print(f"Accuracy 3: {round(len(mapped_df.query('true_label == pred0_thresh_int'))/len(mapped_df),4)*100}%")
# Out:
# Accuracy 1: 84.72%
# Precision: 0.8655
# Recall/Sens: 0.8222
# Spec: 0.8722
# Accuracy 2: 84.72%
# Precision: 0.9195
# Recall/Sens: 0.7611
# Spec: 0.9333
# Accuracy 3: 83.89%

# %%
mapped_df.query("true_label != pred_int")
# Out:
#     img_name  true_label    pred_0    pred_1  pred_int original_image_name  \
# 3      c0035           0  0.063651  0.094966         1        00001645_000
# 12     c0249           0 -0.897105  1.171756         1        00000701_000
# 29     c0426           0 -1.056810  1.293607         1        00000502_000
# 33     c0512           0  0.104742  0.138245         1        00001266_000
# 49     c0926           0 -3.199633  3.537657         1        00001761_000
# 50     c0931           0 -1.280314  1.771777         1        00001447_000
# 70     c1424           0  0.066005  0.141601         1        00000417_002
# 73     c1488           0 -0.025901  0.125242         1        00000184_000
# 77     c1616           0 -0.900130  1.317359         1        00000083_000
# 79     c1658           0 -2.188762  2.542366         1        00000357_000
# 80     c1690           0 -0.157629  0.228803         1        00001620_000
# 83     c1718           0 -0.140538  0.239984         1        00000988_001
# 86     c1825           0 -4.991371  5.341252         1        00000826_000
# 97     c2174           0 -0.416009  0.510613         1        00000105_001
# 106    c2411           0 -0.238484  0.510164         1        00000813_001
# 111    c2471           0 -0.249935  0.378511         1        00000555_000
# 123    c2688           0 -0.286902  0.427319         1        00000623_004
# 126    c2749           0  0.001883  0.360066         1        00000450_007
# 136    c3008           0  0.001529  0.257803         1        00000995_000
# 139    c3073           0 -0.936077  1.125626         1        00000994_000
# 150    c3196           0 -0.337961  0.532345         1        00001397_006
# 177    c3803           0  0.056308  0.087843         1        00001334_000
# 178    c3845           0 -0.841924  1.041023         1        00001777_000
# 189    n0075           1  1.191566 -1.106297         0        00029207_000
# 191    n0099           1  1.228143 -1.112663         0        00001738_002
# 193    n0106           1  0.611931 -0.485985         0        00006517_007
# 207    n0188           1  1.345037 -0.788413         0        00010369_007
# 208    n0194           1  1.279675 -1.189581         0        00007605_000
# 213    n0223           1  0.707399 -0.444287         0        00017123_002
# 218    n0259           1  0.497832 -0.450146         0        00016117_000
# 229    n0316           1  0.468466  0.105790         0        00018785_001
# 232    n0336           1  1.222853 -0.898872         0        00014006_001
# 243    n0382           1  1.236871 -1.141820         0        00000399_000
# 254    n0457           1  0.487548  0.073504         0        00025446_001
# 256    n0471           1  1.233709 -1.142437         0        00012485_000
# 257    n0473           1  1.028215 -0.802515         0        00003101_003
# 261    n0482           1  1.578045 -1.002422         0        00023957_000
# 264    n0492           1  1.315207 -1.019797         0        00014200_000
# 269    n0565           1  0.499986 -0.340598         0        00024281_000
# 270    n0577           1  0.235112 -0.112781         0        00017463_000
# 274    n0602           1  0.330044 -0.197497         0        00003273_000
# 283    n0634           1  0.062652  0.040297         0        00005607_001
# 291    n0690           1  0.927872 -0.697488         0        00002509_000
# 295    n0710           1  0.496687 -0.397431         0        00005024_000
# 307    n0799           1  0.486859  0.175978         0        00020983_000
# 308    n0809           1  0.155925  0.069239         0        00017262_000
# 311    n0825           1  1.212811 -0.621008         0        00027156_000
# 314    n0840           1  0.309066 -0.226586         0        00000695_000
# 320    n0858           1  1.346333 -1.100942         0        00018983_004
# 336    n0975           1  0.549216 -0.134721         0        00000370_000
# 340    n0997           1  1.148432 -1.056996         0        00009955_000
# 346    n1029           1  0.900132 -0.743322         0        00002204_001
# 348    n1040           1  0.914521 -0.716163         0        00000164_000
# 355    n1117           1  1.012659 -0.937260         0        00002513_004
# 357    n1121           1  0.427335 -0.197156         0        00020617_000
#
#     orig_dataset  label        mha Finding Labels  ... orig_bbox_height  \
# 3    chestxray14      0  c0035.mha     No Finding  ...                0
# 12   chestxray14      0  c0249.mha     No Finding  ...                0
# 29   chestxray14      0  c0426.mha     No Finding  ...                0
# 33   chestxray14      0  c0512.mha     No Finding  ...                0
# 49   chestxray14      0  c0926.mha     No Finding  ...                0
# 50   chestxray14      0  c0931.mha     No Finding  ...                0
# 70   chestxray14      0  c1424.mha     No Finding  ...                0
# 73   chestxray14      0  c1488.mha     No Finding  ...                0
# 77   chestxray14      0  c1616.mha     No Finding  ...                0
# 79   chestxray14      0  c1658.mha     No Finding  ...                0
# 80   chestxray14      0  c1690.mha     No Finding  ...                0
# 83   chestxray14      0  c1718.mha     No Finding  ...                0
# 86   chestxray14      0  c1825.mha     No Finding  ...                0
# 97   chestxray14      0  c2174.mha     No Finding  ...                0
# 106  chestxray14      0  c2411.mha     No Finding  ...                0
# 111  chestxray14      0  c2471.mha     No Finding  ...                0
# 123  chestxray14      0  c2688.mha     No Finding  ...                0
# 126  chestxray14      0  c2749.mha     No Finding  ...                0
# 136  chestxray14      0  c3008.mha     No Finding  ...                0
# 139  chestxray14      0  c3073.mha     No Finding  ...                0
# 150  chestxray14      0  c3196.mha     No Finding  ...                0
# 177  chestxray14      0  c3803.mha     No Finding  ...                0
# 178  chestxray14      0  c3845.mha     No Finding  ...                0
# 189  chestxray14      1  n0075.mha         Nodule  ...               68
# 191  chestxray14      1  n0099.mha         Nodule  ...               24
# 193  chestxray14      1  n0106.mha         Nodule  ...               57
# 207  chestxray14      1  n0188.mha         Nodule  ...               43
# 208  chestxray14      1  n0194.mha         Nodule  ...               46
# 213  chestxray14      1  n0223.mha         Nodule  ...               59
# 218  chestxray14      1  n0259.mha         Nodule  ...               73
# 229  chestxray14      1  n0316.mha         Nodule  ...               39
# 232  chestxray14      1  n0336.mha         Nodule  ...               47
# 243  chestxray14      1  n0382.mha         Nodule  ...               28
# 254  chestxray14      1  n0457.mha         Nodule  ...               38
# 256  chestxray14      1  n0471.mha         Nodule  ...               75
# 257  chestxray14      1  n0473.mha         Nodule  ...               48
# 261  chestxray14      1  n0482.mha         Nodule  ...               52
# 264  chestxray14      1  n0492.mha         Nodule  ...               29
# 269  chestxray14      1  n0565.mha         Nodule  ...               69
# 270  chestxray14      1  n0577.mha         Nodule  ...               33
# 274  chestxray14      1  n0602.mha         Nodule  ...               80
# 283  chestxray14      1  n0634.mha         Nodule  ...               50
# 291  chestxray14      1  n0690.mha         Nodule  ...               41
# 295  chestxray14      1  n0710.mha         Nodule  ...               36
# 307  chestxray14      1  n0799.mha         Nodule  ...               57
# 308  chestxray14      1  n0809.mha         Nodule  ...               97
# 311  chestxray14      1  n0825.mha         Nodule  ...               39
# 314  chestxray14      1  n0840.mha         Nodule  ...               69
# 320  chestxray14      1  n0858.mha         Nodule  ...               60
# 336  chestxray14      1  n0975.mha         Nodule  ...               23
# 340  chestxray14      1  n0997.mha         Nodule  ...               42
# 346  chestxray14      1  n1029.mha         Nodule  ...               12
# 348  chestxray14      1  n1040.mha         Nodule  ...               42
# 355  chestxray14      1  n1117.mha         Nodule  ...               62
# 357  chestxray14      1  n1121.mha         Nodule  ...               33
#
#      shared_image_width shared_image_height  Study Year  Manufacturer  \
# 3                  1024                1024         NaN           NaN
# 12                 1024                1024         NaN           NaN
# 29                 1024                1024         NaN           NaN
# 33                 1024                1024         NaN           NaN
# 49                 1024                1024         NaN           NaN
# 50                 1024                1024         NaN           NaN
# 70                 1024                1024         NaN           NaN
# 73                 1024                1024         NaN           NaN
# 77                 1024                1024         NaN           NaN
# 79                 1024                1024         NaN           NaN
# 80                 1024                1024         NaN           NaN
# 83                 1024                1024         NaN           NaN
# 86                 1024                1024         NaN           NaN
# 97                 1024                1024         NaN           NaN
# 106                1024                1024         NaN           NaN
# 111                1024                1024         NaN           NaN
# 123                1024                1024         NaN           NaN
# 126                1024                1024         NaN           NaN
# 136                1024                1024         NaN           NaN
# 139                1024                1024         NaN           NaN
# 150                1024                1024         NaN           NaN
# 177                1024                1024         NaN           NaN
# 178                1024                1024         NaN           NaN
# 189                1024                1024         NaN           NaN
# 191                1024                1024         NaN           NaN
# 193                1024                1024         NaN           NaN
# 207                1024                1024         NaN           NaN
# 208                1024                1024         NaN           NaN
# 213                1024                1024         NaN           NaN
# 218                1024                1024         NaN           NaN
# 229                1024                1024         NaN           NaN
# 232                1024                1024         NaN           NaN
# 243                1024                1024         NaN           NaN
# 254                1024                1024         NaN           NaN
# 256                1024                1024         NaN           NaN
# 257                1024                1024         NaN           NaN
# 261                1024                1024         NaN           NaN
# 264                1024                1024         NaN           NaN
# 269                1024                1024         NaN           NaN
# 270                1024                1024         NaN           NaN
# 274                1024                1024         NaN           NaN
# 283                1024                1024         NaN           NaN
# 291                1024                1024         NaN           NaN
# 295                1024                1024         NaN           NaN
# 307                1024                1024         NaN           NaN
# 308                1024                1024         NaN           NaN
# 311                1024                1024         NaN           NaN
# 314                1024                1024         NaN           NaN
# 320                1024                1024         NaN           NaN
# 336                1024                1024         NaN           NaN
# 340                1024                1024         NaN           NaN
# 346                1024                1024         NaN           NaN
# 348                1024                1024         NaN           NaN
# 355                1024                1024         NaN           NaN
# 357                1024                1024         NaN           NaN
#
#      Modality  subtlety nodule_size  malignant  Partition
# 3         NaN       NaN         NaN        NaN       Test
# 12        NaN       NaN         NaN        NaN       Test
# 29        NaN       NaN         NaN        NaN       Test
# 33        NaN       NaN         NaN        NaN       Test
# 49        NaN       NaN         NaN        NaN       Test
# 50        NaN       NaN         NaN        NaN       Test
# 70        NaN       NaN         NaN        NaN       Test
# 73        NaN       NaN         NaN        NaN       Test
# 77        NaN       NaN         NaN        NaN       Test
# 79        NaN       NaN         NaN        NaN       Test
# 80        NaN       NaN         NaN        NaN       Test
# 83        NaN       NaN         NaN        NaN       Test
# 86        NaN       NaN         NaN        NaN       Test
# 97        NaN       NaN         NaN        NaN       Test
# 106       NaN       NaN         NaN        NaN       Test
# 111       NaN       NaN         NaN        NaN       Test
# 123       NaN       NaN         NaN        NaN       Test
# 126       NaN       NaN         NaN        NaN       Test
# 136       NaN       NaN         NaN        NaN       Test
# 139       NaN       NaN         NaN        NaN       Test
# 150       NaN       NaN         NaN        NaN       Test
# 177       NaN       NaN         NaN        NaN       Test
# 178       NaN       NaN         NaN        NaN       Test
# 189       NaN       NaN         NaN        NaN       Test
# 191       NaN       NaN         NaN        NaN       Test
# 193       NaN       NaN         NaN        NaN       Test
# 207       NaN       NaN         NaN        NaN       Test
# 208       NaN       NaN         NaN        NaN       Test
# 213       NaN       NaN         NaN        NaN       Test
# 218       NaN       NaN         NaN        NaN       Test
# 229       NaN       NaN         NaN        NaN       Test
# 232       NaN       NaN         NaN        NaN       Test
# 243       NaN       NaN         NaN        NaN       Test
# 254       NaN       NaN         NaN        NaN       Test
# 256       NaN       NaN         NaN        NaN       Test
# 257       NaN       NaN         NaN        NaN       Test
# 261       NaN       NaN         NaN        NaN       Test
# 264       NaN       NaN         NaN        NaN       Test
# 269       NaN       NaN         NaN        NaN       Test
# 270       NaN       NaN         NaN        NaN       Test
# 274       NaN       NaN         NaN        NaN       Test
# 283       NaN       NaN         NaN        NaN       Test
# 291       NaN       NaN         NaN        NaN       Test
# 295       NaN       NaN         NaN        NaN       Test
# 307       NaN       NaN         NaN        NaN       Test
# 308       NaN       NaN         NaN        NaN       Test
# 311       NaN       NaN         NaN        NaN       Test
# 314       NaN       NaN         NaN        NaN       Test
# 320       NaN       NaN         NaN        NaN       Test
# 336       NaN       NaN         NaN        NaN       Test
# 340       NaN       NaN         NaN        NaN       Test
# 346       NaN       NaN         NaN        NaN       Test
# 348       NaN       NaN         NaN        NaN       Test
# 355       NaN       NaN         NaN        NaN       Test
# 357       NaN       NaN         NaN        NaN       Test
#
# [55 rows x 31 columns]
